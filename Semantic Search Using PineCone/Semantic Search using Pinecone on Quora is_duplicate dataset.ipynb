# %%
from datasets import load_dataset
import json

# %%
dataset = load_dataset('quora', split='train[100000:150000]')
dataset
# Out:
# Dataset({
#     features: ['questions', 'is_duplicate'],
#     num_rows: 50000
# })

# %%
# View first 2 records
dataset[:2]
# Out:
# {'questions': [{'id': [165932, 165933],
#    'text': ['What should I ask my friend to get from UK to India?',
#     'What is the process of getting a surgical residency in UK after completing MBBS from India?']},
#   {'id': [123111, 39307],
#    'text': ['How can I learn hacking for free?',
#     'How can I learn to hack seriously?']}],
#  'is_duplicate': [False, True]}

# %%
text = []

for ques in dataset['questions']:
    text.extend(ques['text'])

# %%
text = list(set(text))

# %%
text
# Out:
# ['How do I compare the similarity of a string to an item within a list in Python?',
#  '',
#  'How is sensation different from perception?',
#  'Why do body tissues other than the brain have low T2 values for MRI?',
#  'What could be a synonym of "necessary evil"?',
#  'How can I hack the others Facebook account?',
#  'What causes temperature to change daily during each season?',
#  'How did you feel about the ending of Rogue One?',
#  'What is the best craft beer in the USA?',
#  'What is the difference between sex and porn?',
#  'Will Russia and U.S. go to war?',
#  'How should I concentrate on my study?',
#  'Do I have to worry about AI as a computer engineer?',
#  'How do I deal with someone close to me blocking me on WhatsApp and Facebook?',
#  'Why did JFK invite Nazi pilot Hanna Reitsch to the White House?',
#  'How to learn MATLAB?',
#  'I am an MBA graduate. I am looking for specialization courses in marketing. Can you suggest any such courses abroad?',
#  "What effects will Andrew Cuomo's visit to Cuba in 2015 have on tourism in Cuba and the U.S.?",
#  'What is the difference between embed and object in html?',
#  'What companies does Donald Trump own?',
#  'How can I download my e-Aadhaar Card?',
#  'What were the best music albums of 2016?',
#  'Who solved the Great Depression?',
#  'How can an African guy get a white girl?',
#  'What is the most important thing about traveling to you?',
#  'How do I turn white hairs into black?',
#  'If you were to have a superpower, what would you like it to be?',
#  'What is the difference between Python scripting and object-oriented Python sevelopment?',
#  'If I write an open source platform to be used for a Silk Road type website, would I be breaking the law?',
#  'What are the most productive ways to spend time on the Internet?',
#  'How do you write an application for a leave of absence?',
#  "What effects will Andrew Cuomo's visit to Cuba in 2015 have on real estate in Cuba and the U.S.?",
#  'What is TCS BPS? Is it a good option to join? Is it anywhere related to bpo job?',
#  'Why should India consider to review Indus Water treaty?',
#  'What can cause the back left side of my neck to feel so tight, could it be serious? ',
#  'How do you get out of boredom?',
#  "Which countries are Israel's best allies?",
#  'How do I get listings from homeowners for my vacation rentals website?',
#  "What are your thoughts on Apple's iPhone 7 and other new products announced on September 7, 2016?",
#  'Why do teens swear?',
#  'Why do some people say that Donald Trump is racist?',
#  'Why does the UK compete as the UK in the Olympics but as individual countries in the World Cup?',
#  'What is the nullification crisis?',
#  'What led to the decline of the Ottoman Empire?',
#  'What are some things new employees should know going into their first day at Douglas Dynamics?',
#  'What are the famous tourism places in Pakistan?',
#  'When is surge pricing on Uber generally in effect in Queens and how high does it go?',
#  'How do I find my first job?',
#  "What are do's and don'ts when traveling to Germany?",
#  'How does sex feels?',
#  'Who is the person responsible for sourcing and purchasing in a company?',
#  'What questions to ask the CEO and founder of an organization during interviewing?',
#  'Where can we download Microsoft Office for free?',
#  'How do I prepare for KVPY SX with 3 months left for exam?',
#  'Should the UK stop giving aid to India?',
#  'What are some unexpected things first-time visitors to Gabon notice?',
#  'Why should I sleep without a bra?',
#  'Is Tumblr a good marketing channel for porn sites?',
#  'How is the experience of working in AAI?',
#  'I have a Delhi state OBC certificate (jat). Is it valid?',
#  'What are non-valence electrons?',
#  'What is the best joke you have heard?',
#  'Why should I not care about what others think?',
#  'What is a good book/resource on learning self-defense for beginners?',
#  'What are the best resources to learn about sign language?',
#  'What are some comfort zone challenges?',
#  'How can I attach pdf file in email mailmerge using word 2013/2016?',
#  'Why do programmers hate optimization?',
#  'Do people in India follow Ramayana? How?',
#  'Given recent Uri attacks, who will win if there is a war between India and Pakistan?',
#  'Why do people wear wristwatch on right hands?',
#  'How was thrash metal invented?',
#  'Why is it difficult to ride a bicycle on sand?',
#  'What skill should I learn?',
#  'Is it a bad idea to book the cheapest Expedia flight available?',
#  'Does criticism of public figures and celebrities violate Quora BN/BR policy?',
#  'How did the cold war screw up Afghanistan?',
#  "Who is Darth Vader's mom?",
#  'Is there a way to view private Facebook profiles without being a friend?',
#  'How do I make a website look exactly the same on desktop as on mobile?',
#  'Which one is better between B.Tech and L.L.B, or a B.A L.L.B? Why?',
#  'How does it feel to live in Saudi Arabia as an expatriate?',
#  'Can I revive a pair of black leather Dr Martens that have been scratched and scuffed?',
#  'How is American Express as compared to Morgan Stanley for summer intern 2016? American Express is paying more than 2.5 times Morgan Stanley.',
#  'Are there any sensors available for checking nutrient levels in the soil?',
#  'How do I become an entrepreneur?',
#  'Why do companies buy companies?',
#  'Can a tiger kill the lion?',
#  'Can I get pregnant a week after my cycle?',
#  'What does it mean if my new girlfriend talks a lot when I meet her what does it mean? Is this a good thing? Also she talks a lot of her problems',
#  'What does it feel like being a US Marine in Afghanistan or Iraq?',
#  'How frequently can I trade in and out of stocks using the Robinhood app?',
#  'What percentage of people believe man has landed on moon?',
#  'What is computer networking?',
#  'What was the decision of the court for the Marbury v. Madison case?',
#  "How could Hitler ''brain wash'' so many people, and persuade them to agree with his ideology?",
#  'What are the uses for dragon blood in "Harry Potter"?',
#  'What are some good ways to make apple pie?',
#  'What is difference between cryonics and cryogenics?',
#  'Is it true that Quaker Oats can cause cancer?',
#  'Are non-Muslims who reject Muhammad and resist Islamic rule considered to be "innocent persons" in Islam?',
#  'Can we use mobile phones on an airplane?',
#  "The Three Kingdoms Period in Ancient China: What are some anecdotes of Zhang Liao's extremely high intelligence?",
#  'What are the best mobile ad networks in Korea?',
#  'Which is better, Red Dead Redemption or Red Dead Revolver?',
#  'Beteen Samsung Galaxy j5 and ASUS zenfone max which is better?',
#  'How do I learn blueprint reading by myself?',
#  "What's the best thing to say to someone who is depressed?",
#  'What are the primary similarities between stage acting and film acting?',
#  'What will you do in the last day of your life?',
#  'What is the best book on heat and mass transfer?',
#  'How does a first kiss feel?',
#  'What is a striker-fired 9mm?',
#  "Is the left's hatred of Donald Trump a sign that they are out of touch with working class problems and values?",
#  'What is your biggest regret of your life?',
#  'How can you tell that a girl is sexually satisfied during sex?',
#  'What is the national highway of India?',
#  'Has anyone had any success using onion juice to regrow their hair?',
#  'What were the major effects of the cambodia earthquake, and how do these effects compare to the Iquique earthquake in 1877?',
#  'Do alien abductions really occur?',
#  'How do I satisfy a girl during sex?',
#  'How can I find inverse of a matrix in GF(256)?',
#  'Which is the best app for earning money?',
#  'What is the most interesting thing about Japan?',
#  'How were dead-end streets formed in India?',
#  'What are the best online free resources to learn how to speak Telugu?',
#  'Do srikrishnadevaraya really belong to kapu caste as it said by kapu caste people of andhra pradesh?',
#  'How can I make tomato sauce for a chili recipe?',
#  'How do we currently measure the speed of light?',
#  'What is the oxidation state of nickel? How is this determined?',
#  'What are the best love stories you have written or read somewhere?',
#  'I\'m going to Paris. What is the equivalent "neighborhood" of Paris to the Mission in San Francisco, or Williamsburg in New York?',
#  'Which is better to call our country, India or Bharath?',
#  "Granted I'd be ok sharing my idea with the world, can publishing a press release lead to inbound investor intros if the signs are there?",
#  'How is the review of "ae dil hai mushkil" Bollywood movie?',
#  'How do I stop thinking of something?',
#  "Will the scraping of 500 and 1000 rupees have negative effect on Indias's economy?",
#  'I want to start programming, what language should I learn?',
#  'What is the scariest story you have ever heard?',
#  'How can I get out from addiction?',
#  'Where do they drop nuclear bombs during testing?',
#  'I am 21 years old. How can I increase my friends? I do not feel comfortable with new people. How can I overcome this fear of being with people?',
#  'How do I stay motivated at my internship?',
#  'Why do Haredi & many modern Orthodox Jews reject the open orthodoxy movement?',
#  'What is the best tanning lotion for tanning beds?',
#  'What is translucent powder? What does it do?',
#  'What should I do to enter hollywood?',
#  'What is the best blogging platform 2012?',
#  'When will there ever be a cure for autism?',
#  'How can one earn money on Quora?',
#  'I like a girl but she has a over protective BF. Her best friend is on FB and sometimes we talk to each other. How do I make her my girlfriend?',
#  'What is the type of expense in opening a business current account required for a startup?',
#  'Where can I get best photo booth hire in and around Sydney?',
#  'What is the best correspondence study material for IBPS PO preparation?',
#  'What are some rare but useful English words?',
#  'What is generator capability curve?',
#  'How have scientists tried to refute the theory of evolution by natural selection since Darwin proposed it?',
#  'Why do I always get a notification from Quora that my questions "need improvement"?',
#  'Is there anything I can buy that will make water boil faster?',
#  'How can I understand entropy and enthalpy in terms of everyday examples?',
#  'What is the most embarrassing moment your crush had in front of you?',
#  'How do I add my Yahoo mail account into the MS Outlook 2016?',
#  'How do I forget a girl I have feelings for?',
#  'How do I improve my vocabulary and fluency in english daily?',
#  'Why did Eric Blair write under the pen name of George Orwell?',
#  'My ex-girlfriend liked my pictures on Facebook and then blocked me shortly after. What does this mean?',
#  'What are some good TV shows to watch in the second half of 2015?',
#  'How do I edit the theme in WordPress?',
#  'Which are the best institutes for Salesforce CRM in Bangalore?',
#  'What is meant by perception of truth?',
#  'How can I sell art?',
#  'What is the most important thing to look for in a commercial real estate CRM?',
#  "What's the difference between Java and Java script?",
#  "I haven't studied chemistry The university I have to apply requires that SAT2 exams for chem must be given.How much time is needed for preparation?",
#  'What might be a good name for a college magazine?',
#  'What is your team for Pokemon Sun and Moon?',
#  'Can PayPal be trusted?',
#  'How does one comfort a friend who just lost a loved one?',
#  "Is The Alchemist Paulo Coelho's best book?",
#  'Has NASA spoken out why the Apollo missions were cancelled? How did NASA scientists and astronomers view this decision?',
#  "I have Moto G which has Corning Gorilla 3. Does that mean the screen won't get scratches if I don't put on a screen guard?",
#  'When will I stop thinking about what other people think?',
#  'What are the laws regarding license plate lighting in Ontario and what fines are associated? How do these differ in Quebec?',
#  'What do you want for Christmas (2015)?',
#  'Which is the best online store?',
#  "In Shakespeare's plays is there a father expressing his fatherly love for his son?",
#  'How can we find good non-profit organisations or social enterprises in China to volunteer for?',
#  "Why didn't Google integrate Allo into Messenger or Hangout?",
#  'What is the origin of the term "startup", and when did this word start to appear?',
#  'Why do many Europeans think Americans are "dumb" even when the U.S. has the highest GDP in the world?',
#  'Which affiliate programs allow trademark bidding?',
#  'Why in the whole universe gravity causes centripetal force?',
#  'What are the pros of sweatshops?',
#  'Worms (animal): What does it feel like to have a tapeworm?',
#  'How can we convince a girl for sex?',
#  'Why does current flow opposite the direction of the field inside the battery?',
#  'How do I solve the permutation problem with repetition?',
#  'What all would you do if you had one month left before leaving Bangalore for a long time?',
#  'What can be the Themes for a toastmasters meeting?',
#  'What are the differences between a BB gun and an Airsoft gun?',
#  'How would you go about finding transaction comparables for a private equity/venture capital firm? Any examples of PE/VC firms being acquired?',
#  'What are the culture differences between Chinese and Western?',
#  "What religious freedom do you feel you don't have in America?",
#  'Which are some good quality mild sulfate-free shampoos? Where can I avail them?',
#  'Is Amity Uuniversity a good option for an MSc actuarial?',
#  'Why is the Android file system so complex?',
#  'What is the meaning behind the "Bring Sally Up" song?',
#  'What is the best way to learn spoken English with fluency?',
#  'Is Lionel Messi currently the best soccer player in the league? Why or why not?',
#  'What is the analysis in the poem "Touched by an Angel" by the author Maya Angelou?',
#  'What breed is my dog?',
#  'Does hair stop growing at a certain length?',
#  'Did the Clinton foundation only use 10% of the contributions for charity?',
#  "Hi I don't smoke weed, I don't enjoy alcohol, I don't smoke cigarettes. I don't do any drugs. Am I missing something?",
#  'How should I install Windows on Mac?',
#  "What do you think of Elon Musk's plan to colonise Mars?",
#  'How can one "let loose"?',
#  'What is the difference between a graduate of mechanical engineering and a mechanic?',
#  'Can a for profit company turn into a non profit company?',
#  'Was Tendulkar a failure in Australia?',
#  'What is the best way to prepare for NEET 2018?',
#  'How do I make people fall in love with me?',
#  'How do I retrieve deleted Facebook messages?',
#  'What is Superdry in Japan?',
#  'What is a market demand curve?',
#  'How can I get rid of under eye dark circles?',
#  'Why did Quora change its font?',
#  'Why do some women cheat on good guys?',
#  'What was used as bath or wash soap before civilization and industrialization?',
#  'Why does my PC keeps crashing for no reason?',
#  "How can I download cool stuff on my iPhone like they have on Cydia cause I'm not jailbroken?",
#  'Is there any way to increase conversion rate?',
#  'Top bikes in India?',
#  'What are the top 10 TV shows ever made?',
#  'Gaming PC built with i5 6600 Gtx 1060 with wifi card under 65k?',
#  "What factors do I have to thoroughly think about if I want to continue to a Ph.D. from a master's in the same lab?",
#  'Is Lionel Messi a good captain?',
#  'Are there uncurious people?',
#  'What are the 5 findings of the Human Genome Project?',
#  'How does 3 Ballerina tea work?',
#  'At what temperature does a standard ink (such as a bic pen) freeze?',
#  'What appeals to Sensors and Intuitives more respectively: Instrumental or Vocals music?',
#  'What is the best way to get a scholarship?',
#  'What is your opinion on zoos?',
#  'How should I prepare for the IES from the first year?',
#  'How do you syndicate a loan?',
#  'Do we need a pancard for making an indian passport?',
#  'Which book is necessary and sufficient for Geography optional??',
#  'What is a good solution to forget someone?',
#  'What occurs during anaphase?',
#  'Does masturbation cause a vicious cycle by reducing penis sensitivity, which makes one have to masturbate longer or harder to reach orgasm, which further reduces penis sensitivity?',
#  'How is barium sulfate dihydrate formula determined?',
#  'How do we find the number of trailing zeros at the end of a factorial?',
#  'Is there life beyond earth?',
#  'Where is streaming analytics largely used?',
#  'What universities are studying torsion field physics?',
#  'How do I convert an MA4 file to an MP3 file in iTunes?',
#  'What are the demographics of Indian users on Quora?',
#  'What are some characteristics of photosynthetic protists?',
#  'What are some things new employees should know going into their first day at Adtran?',
#  'What are good ways to tenderize chicken breast?',
#  'What is required for a CSE student from a Normal Engineering college to get into the ivy league colleges in the US and Europe? Detailed please.',
#  'What is part time work from home?',
#  'What type and how much of extra curricular activities are required in order to get admissions in the US universities?',
#  "If parallel universes existed, wouldn't there be a parallel universe where parallel universes don't exist?",
#  'How is Treknocom Engineering services, Pune?',
#  'How does it feel to be called fat by someone fatter than you?',
#  'What is the best strategy for Argentina to defeat the Netherlands in the 2014 World Cup semifinal match?',
#  'How do I become a quick learner in life?',
#  'How should I concentrate on studies?',
#  'Who are the best angel investors of all time?',
#  'What is the purpose of a resistor in a circuit and how could it be used in a circuit?',
#  'What is end music?',
#  'What do you mean by investment?',
#  "What's the funniest thing that's ever happened to you?",
#  'Does Bill Gates use Google or Bing?',
#  'What is the difference between having an ego and having self esteem?',
#  "What's something unusual you said or did during a job interview that got you hired?",
#  'How can I develop good scientific research questions?',
#  'How defensible are user interface patents?',
#  'What is the most logical religion and why?',
#  "What's a good book on corporate finance?",
#  'Who won the 2nd presidential debate?',
#  'What are some 5 daily habits that every human being must adopt?',
#  'How do tympanic membranes work in frogs?',
#  'Who was the original drummer for Blink-182?',
#  'What is the difference between an agnostic theist and an atheist?',
#  'Which one is better, Career Launcher or Time?',
#  'What is galileon transformation?',
#  'Visa (payments): Can I make profit online by selling stuff on amazon under OPT F1 status? I am employed, just wanna make extra money.',
#  'How much does movie streaming on Netflix cost?',
#  'Why do Scottish men wear kilts?',
#  'How do movies leak online?',
#  'My boyfriend is judging me because of a sexual fantasy. What should I do?',
#  'Is time travel to 2010 possible?',
#  'Should I do 10 sets of 10 push-ups or do 3 sets of my max push-ups?',
#  'What happens to income inequality if AI replaces skilled workers like how outsourcing has replaced manual workers?',
#  "What's the difference between peanut and groundnut?",
#  'Jessica Hische: Have you ever felt aimless or lost on your career path? What did you do?',
#  'Who is your role model, why?',
#  'Which drug is causing the most problems in your local area?',
#  'Why would anyone with a functioning brain start smoking cigarettes?',
#  'What are some good books?',
#  'What is the difference between Indian engineers and engineers from other countries? Any incidents to show the difference are welcomed',
#  'What is the Law of Tort in construction?',
#  'What is a good inpatient drug and alcohol rehab center in Clark County KY?',
#  'Is required 2000 Rs notes?',
#  'What is TR means in terms of salary?',
#  'What should you take into consideration when driving from Brooklyn to Staten Island, and how does it compare to driving from Brooklyn to the Bronx?',
#  'I wanna start preparing for ias exam, how should I proceed?',
#  'Do teachers actually fall in love romantically with certain students? Even when a male teacher is 20 years older?',
#  'What physiological tricks are useful to know?',
#  'Why does my boyfriend put his fingers in my mouth during sex?',
#  'Is Quora becoming more or less like Facebook?',
#  'How is a typical day of an MTech CSE student at the IITD? How many lectures are conducted daily for MTech students?',
#  'How do I know all about a life insurance policy?',
#  'What are some of the best lyrics in a romantic song?',
#  'How do I post my article on mashable?',
#  'Lets say that gravity turned off for 5 minutes max. What would happen to earth and the people on it?',
#  'How can I stop obsessing over my skin?',
#  'What makes human a social creature? Why do we need emotional support in life?',
#  'Why does the 100% charge on an iPad last longer than the other levels?',
#  'Entertainment before you were born.?',
#  'What is the difference between metaphysics and philosophy?',
#  'Why does it seem like early polls were so inaccurate in terms of actual 2016 presidential election results?',
#  'Which music download is the best?',
#  'Why am I so unmotivated to workout or eat healthy to lose fat even though I know that I might get a stroke or die very young because of my obesity?',
#  'Can Trump actually force Mexico to pay for the wall?',
#  "What does the Quora community think of Trump's statement that he will only accept the results of the election if he wins?",
#  'How do you create an array in PHP?',
#  'Why can Lip in Shameless go home back and forth from MIT campus so frequently?',
#  "What are some of your New Year's resolutions for 2015?",
#  'What is the longest river in the world?',
#  'How do I search in Quora?',
#  'What are some research papers for internet usage and cybercrime?',
#  'Why do some people say Margaret Thatcher was bad?',
#  'What was the best happening or moment in your life?',
#  'Who are the best responsive web designers in Kerala?',
#  'What are some show and tell ideas that begin with the letter "J"?',
#  'What are the essential skills for a mechanical engineer to be employable?',
#  'I purchased a big embroidered fabric bag in China and it smells like kerosene. How can I remove the smell?',
#  'I want to decrease my thigh and buttock sizes very, very badly. How do I do it?',
#  'What are some easiest exercises to burn calories fast?',
#  'What is my artwork missing that separates me from a professional?',
#  'Which app is the best app to root device?',
#  'What is preferable to do after finishing the BBA in audit?',
#  'Is the real Wolf of Wall Street Jordan Belfort still rich today?',
#  'How did Theodore Roosevelt help regulate big businesses?',
#  'What cities do born and raised New Yorkers most frequently move to?',
#  'What are the best WhatsApp sttatus?',
#  'What is the best python project?',
#  'How could we humans achieve world peace?',
#  'Which is the best IAS (2017 course) institute for correspondence?',
#  'Which one is the best water purifier to buy among kent, pureit, a.o. smith and aquarguard, if I am buying the best one for each company?',
#  'How do I be intelligent?',
#  'What is the best way to clean a spray bottle before reusing it?',
#  'Is there a difference between psychiatrist and psychologist?',
#  'Who is the most popular singer in us history?',
#  "I'm a 15 year old male and want some advice on having sex. What should I know when the time comes?",
#  'How do I book bulk tickets on IRCTC?',
#  'How will a Trump presidency affect the rest of the world?',
#  'What is the future of petroleum engineering as a career choice?',
#  'With ABC announcing a "Inhumans" TV series for 2017, will the "Agents of S.H.I.E.L.D." be cancelled?',
#  'When we download free apps from Google stores, app asks permission to access information such as photo, contacts, etc. How safe to accord permission?',
#  'Western Illinois Football Live Stream | Watch Western Illinois Leathernecks Football Game Today Live Streaming Online?',
#  'What is GDP? How is it calculated?',
#  'How was your experience while complaining on the Anti Corruption Helpline 1031 launched in Delhi by Kejriwal?',
#  'Are supporters of lower-league football clubs more interesting than fans of Premier League teams?',
#  'When can employees exercise their stock options in a company?',
#  'What questions have the best Answer Wikis?',
#  'Are there people in the world who dont know and dont care about how old they are?',
#  "What is the third largest island in the Malay Archipelago, and how does its wildlife compare to Upolu's?",
#  'Is AM engineer in Nokia better or associate at Cognizant with Google Maps and will work in Google Office?',
#  'Why is it difficult for America to break out of the two party system?',
#  'Where is the Indian currency printed in India?',
#  'Can I do supersets for strength?',
#  'What are signs that a relationship will become abusive?',
#  'When did racial segregation begin in the US and when did it end?',
#  'Where can I find a website to watch movies with English subtitles?',
#  'What might be a good name for a premium online fragrance store?',
#  'Visiting and Travel in Paris: Is buying Museum Pass (4 day) worth to avoid queues for <26y.o. student?',
#  'Which book is best for theoretical study of physical chemistry (please specify the edition as well)?',
#  'What are some tricks to learn Java quickly?',
#  'Can a CT scan show cancer?',
#  'Difficulty level of ESE 2017?',
#  'How can I plan and book a cheap domestic flight?',
#  "I'm pretty fed up with Quora telling me my questions need improving but not giving me enough characters to improve them! Why is that?",
#  'How was the Post-It Note invented?',
#  'Has there ever been a true communist country?',
#  'Are people who lack abstract reasoning morally inept?',
#  'Why do women fake orgasms?',
#  'What are the new project ideas for Mechanical Engineering students?',
#  'What are the best Laravel plugins for analyzing database data?',
#  'How dangerous is that weight loss surgery?',
#  'Which is the best TV serial in Hindi language?',
#  'Why is America silent about what is going on in North Korea?',
#  'How credible and useful is the World quant university Masters in Financial Engineering degree?',
#  'Are you satisfied with your accomplishments in life?',
#  'Which is the best food to gain weight?',
#  'Where can I get wonderful flavors on cupcakes in Gold Coast?',
#  'How can I build a homemade drone?',
#  'Has a major American presidential candidate ever called their opponent "the devil" before Trump?',
#  'How can I trace my stolen Fitbit?',
#  'Would it be possible to power MBTs (Main Battle Tanks) with fission-type nuclear reactors by today’s standards in large series?',
#  'Is it necessary to have sex in relationship?',
#  'Is it normal to have pimples on armpits and groin?',
#  'How can I move to US as a boxer?',
#  'How do you permanently delete your Yahoo account?',
#  'U.S after Donald Trump wins the US presidential election?',
#  "Can you teach me English and I'll teach you Chinese?",
#  'What is the chemical symbol for Tungsten?',
#  'Why are 2000 rupee notes purple?',
#  'How do I create an application for Android?',
#  'What are some good books for stargazing in India?',
#  'How can Deadpool die?',
#  'What are the best ways to market an Android app?',
#  'How do the tourist attractions on the Scandinavian Highlands compare to attractions in Ukraine?',
#  'How should I start my preparation for the SSC CGL 2017 without coaching?',
#  'What are the geekiest status on WhatsApp?',
#  'What fuel system powers the Curiosity Mars Rover?',
#  'What are some innovative ideas for sustainable design and construction?',
#  'Which is the best card swapping machine available in India?',
#  'What is the best way to get over a girl you love and that broke up with you from a 5-year relationship just because she was afraid to tell her parents?',
#  'Is it ok to hate someone who was detrimental to ur being?',
#  'Is Slim Shady dead?',
#  'What is the best time of day to go on a walk?',
#  'What are your favourite fruits and vegetables?',
#  'What are good ways to emotionally connect with other people?',
#  'What proposal can I keep for a data entry job?',
#  'What will we eat in the future?',
#  'How do you get rid of a pimple on your earlobe?',
#  'Does love happen only once in a lifetime?',
#  "Is Hillary Clinton's political career over?",
#  'What dangerous situations have you successfully handled before?',
#  'What is a post on Quora and how and why is it done?',
#  'What is the best way to control your anger?',
#  'What is the best way to restore a Dell Inspiron 530 to factory settings?',
#  "I'm working as an NOC engineer and want to switch to IT (Software), how ?",
#  'How does a pressure sensor work?',
#  'What question can you ask someone that will spark deep, interesting conversation?',
#  'When we add starch to iodine solution why does the colour of the solution turn blue?',
#  'What are good qualities of Indians which no other countrymen have?',
#  'What is the meaning and purpose to life?',
#  'How long would it take Trump to take down the clean energy tax breaks?',
#  'What are your reviews about the magazine 7tint.com?',
#  'What happens to consciousness after death?',
#  'Why is perrhenate not a strong oxidizing agent, despite the fact that it contains rhenium in huge oxidation number +7?',
#  'How do I get good job as web developer?',
#  'How do I get ripped?',
#  'Can I commit suicide?',
#  'How can we change IMEI on S7 edge?',
#  "How has Bollywood corrupted the Indian youth's perception of love?",
#  'What hobbies involve researching, discovery, innovation, or experimentation?',
#  'Is being humble a weakness?',
#  'Android (operating system): Is iOS better than Android and Windows Phone?',
#  'Do driver-by downloads install/run automatically?',
#  'How true is the Roswell UFO incident?',
#  'Is a narcissist indestructible?',
#  'Which companies have the best data science teams?',
#  'Why did Colombian citizens reject the FARC peace deal?',
#  'How can I be a good writer?',
#  'I have a fantasy about being kidnapped and gay raped. Is there anyone willing to do this to me?',
#  "What does this passport status mean: 'Police reports have been submitted by your respective Thana and is under review at the SP Office'?",
#  'What job does Jake Williams have?',
#  'What are some good locations for photowalks in delhi?',
#  'How can I download YouTube videos & audios?',
#  'Why do more men commit suicide than women?',
#  "Which school is better for a master's in computer science, NYU Poly or Syracuse?",
#  "What's the difference between and drug test and a drug screen? Also do labs take hair samples for drug screen?",
#  'What is the best chess app that will help me learn?',
#  'What was the most racist encounter in a country you visited as a tourist?',
#  'How is IBS Pune for MBA and does PGPM equally good?',
#  "I'm starting as a control engineer after my PhD in control systems. What steps should I make now to maximize my career ambitions?",
#  "Why do people find India's batting more interesting than bowling?",
#  'Why are many Quora writers lonely and/ or unemployed?',
#  'Which is the best cricket coaching academy in india?',
#  "What are the countries where I don't need recommendations for getting admission to a graduate program in a university?",
#  'What is self awareness and what are some examples?',
#  'Can an overdose of Bisoprolol kill you?',
#  "What is the difference between '#' and '##' in C?",
#  'Where do most natural disasters take place?',
#  'Which smartphone has the best camera?',
#  'What do you do when your manager keeps picking on your behaviors?',
#  "What will be benefit to us with modi's Gold scheme?",
#  'How can we develop our critical thinking abilities?',
#  'Which is the best service daikin air conditioner service center in hyderabad?',
#  'Donald trump: what could happen if Donald Trump becomes president?',
#  'What is the goal of maths?',
#  'Are there chat rooms for making friends in XBox 360 Live games?',
#  'What are the allegations that Arvind Kejriwal made and proved them in the court?',
#  'What is the difference between rice vinegar and rice wine vinegar?',
#  'Why do some people think the Earth is flat?',
#  'Does porn harm your sex life?',
#  'Can the most known and prettiest girl at school like a dweeb that sits next to her during lunch and the bus?',
#  'How can I find the aim of my life?',
#  'Batman (creative franchise): Why does Harley Quinn love The Joker?',
#  'Will a 275 70r 17 size tire fit on a 17"x7" (maybe 7.5" width) inch wheel that has an 265 70r 17 size tire as the stock reccomended tire? ',
#  'How does it feel when your best friend falls in love with you?',
#  "What are the best new inventions that most people don't know about?",
#  'Was Harry Potter religious if he chose to give his son Albus a godfather?',
#  'What is the best way to buy shares?',
#  "What are good gifts for a foreign visitor to bring when they're invited to someone's home in Denmark for the first time?",
#  'Is it illegal to follow a celebrity for a long period of time?',
#  'Can you get high if your outside and someone is smoking weed like 20 feet from you?',
#  'Which is a suitable inpatient drug and alcohol rehab center in Delta County CO?',
#  'How long does it take to learn Arabic enough to understand Quran?',
#  'Which company provides the best SEO services in Delhi?',
#  "What are some creative ideas for arranging a freshers' party?",
#  'How can I overcome fear in public speaking?',
#  'How do you make another Instagram account?',
#  'Anyone pl; tell me how can I talk to airtel customer care executive?',
#  'How do ferrous fumarate and ferrous sulphate differ?',
#  'Which book is better for gre?',
#  'How are alpha helix structures of proteins stabilized?',
#  "Why do some people think it's impossible for white people to face racism and discrimination?",
#  'Was President Urho Kekkonen, the Father of modern Finland, a very strict ruler?',
#  "Would catamarans and trimarans have fared well as large scale military ships (let's say in the 18th and early 19th century)?",
#  'People think I am weird and avoid me because I am quiet and avoid small talk.  I have tried my whole life to change this, but it seems that I am just a born introvert.  How can I change, and should I change?',
#  'How does Herbalife make you lose weight fast?',
#  'I am a civil engineer. What are the future prospects and job opportunities if I complete a PG in furniture design from NID?',
#  'If you have a high GMAT score, should you include it on your resume?',
#  'How do you tell someone that they are lying to you?',
#  'Under what circumstances would the production possibility curve bowed?',
#  'How do I solve the equation m/6-4=9?',
#  'How is Sardara Singh (hockey) in real life?',
#  'How did Hernan Cortes die? When did it happen?',
#  'What are the best ways to forget the past?',
#  'Do you believe in ghosts? Are they really real?',
#  'How do open refrigerators for vegetable stores work?',
#  'Which are the MOOCs developed by universities of Spain similar to edX, Coursera, the Khan Academy, the NPTEL or the MIT OCW?',
#  'What does closing a book mean in accounting?',
#  'How do you blow-dry your curly hair straight?',
#  'Is there any evidence that extraterrestrial beings exist?',
#  'Can anyone provide me an authentic recipe for mughlai goat qorma or refer to the right website?',
#  'Which laptop should I buy that is around INR 50,000?',
#  'Can people of any race have freckles, or is just white people?',
#  'Why do people ask such intimate questions on Quora?',
#  'What is the difference between jealousy and admiration?',
#  'What are the emerging New York City tech startups?',
#  'How can the U.S. convince the world that the U.S. is upholding the UNCLOS by refusing signing the UNCLOS?',
#  "In which order should I read Sherlock Holmes' novels and stories?",
#  'Which is a suitable inpatient drug and alcohol rehab center in Burke County GA?',
#  'What is the programming language to learn?',
#  'Instagram: is using too much hashtags vulgar?',
#  'What are some of the best investment strategies?',
#  'Why most of the girls make fun of shy guys?',
#  'What are the different styles on Chase debit cards?',
#  'How do I download torrents using UC browser and utorrent app in my smartphone?',
#  'What was the first question asked on Quora?',
#  'What are ways to make money online at home?',
#  'Which is the best option for a computer geek: BCA or B.Tech?',
#  'I heard there is a website where I can get an EIN number for free. Which website is it?',
#  'What can be a part time job?',
#  'When you finish a plate clean in a fine-dining restaurant, does that make you look starved and classless? Should you leave at least some amount of it?',
#  'According to the theory of evolution, why do we die?',
#  'What does "virtually" mean?',
#  'How do get quality backlinks without guest blogging?',
#  'What is miniaturization of analytical methods?',
#  'Are there hidden apps on my phone?',
#  'What number is the current pope?',
#  'Should you raise girls differently from boys?',
#  "My Instagram is showing past users I've searched before when I type the first 2 letters even after clearing the history. How do I delete or restore that?",
#  'Why does the same person always appear on top of the likers on Instagram pictures?',
#  'What is a boiler?',
#  'Can we do self-charging for smart watches or smart phones by body motion or even heart beat pulse?',
#  'What is the best response when someone talks to you and you do not care to talk to that person?',
#  'What makes you most proud of your country?',
#  'What experience/s have you or someone you know had with a sociopath?',
#  'Did the bush tax cuts work?',
#  'What can Americans do to get drug prices lowered as they pay more than any country for prescription drugs?',
#  'What are the signs of being in love with girl?',
#  'What are the similarities between Donald Trump and Hitler?',
#  'Which strategy does quickly and merges sort use?',
#  'For a women in the Olympic Games, if her scheduled match is on the same day of her Periods, then what she/they do?',
#  'Are you supposed to wear boxers/briefs when wearing lederhosen?',
#  'Is political correctness valued more than factual correctness in Quora?',
#  'How can you determine the Lewis structure for sulfuric acid?',
#  'What did Henry VIII look like?',
#  'What words rhyme with "me"?',
#  'What are some unique ideas for a 13th birthday party?',
#  'Which games I can play on Intel i3 (5th Gen) 4GB RAM with HD 5500 Graphics?',
#  "What's the greatest advertisement you've ever seen?",
#  'Does the scent or the smell of cooked food affect electronics like PS4?',
#  'Who was Abraham Lincoln?',
#  'How do you get rid of a addiction?',
#  'How can I safely lose weight dramatically?',
#  'Where do girls pee from?',
#  'Which is the best restaurant in Aurangabad?',
#  'Why do people eat cat meat?',
#  'What are some good marketing strategies for music?',
#  'Could an immensely large ball of charge possibly pull an object that has crossed the event horizon of a black hole?',
#  'What are the top Linux distros?',
#  '2003 5.7engine trying to put in a 95 chevy tahoe how to it?',
#  'What card games use jokers?',
#  'How do I go about shorting the Toronto housing market?',
#  'How friendly are Beagle Australian Shepherd mixes?',
#  'What should I do if I feel like committing suicide?',
#  'Why do they name bastards Snow?',
#  'When you order from GrubHub does the "Delivery Charge" go to the driver, or should I tip him/her separately?',
#  'Is it OK for my boyfriend to have his female friends stay over?',
#  "What's the best screen recorder if I want to record 1080p 60fps lossless?",
#  "Why shouldn't you use Drano in a dishwasher if it's draining slowly?",
#  "What's stopping the Modi government from appointing Lokpal?",
#  'How do I irritate someone?',
#  'Is white discharge during late period (15 days) common or is it a sign of pregnancy?',
#  'Is there a scientific name for what existed before the Big Bang?',
#  'Why do our faces look puffy in the morning just after waking up?',
#  'Why did the fruit "apple" retain its name as "apple", since it originally referred to other fruits and other fruits became specifically named?',
#  'How can we get partnership and investors for e-commerce?',
#  'Can you add topics to a question? How?',
#  'What is the best way to approach a woman walking in front of you?',
#  'What are some innovative and interesting event ideas for a college fest?',
#  'Can you have sex with a gal in her periods?',
#  'What are the wittiest responses to, "why are you still single"?',
#  'What do I gift my boyfriend for his birthday?',
#  'How can I get better grades in school?',
#  'Since this email scandal with Clinton will possibly never see a court room, will future lawyers be able to use this as reference if it happens again?',
#  "What's the difference between influence and manipulation?",
#  'How much does it cost for ICL surgery in Chennai? Which is the best hospital?',
#  'What is the difference between lac and lakh?',
#  "Why must physicians remove people's limbs with diabetes?",
#  'What are the tips and hacks for getting the classes that you want as a freshman at Union College?',
#  'What did hiro mashima say about natsu being in love with Lucy?',
#  'How would you be able to solve this math problem?',
#  'Why are some people evil? Are they born that way or does life make them evil?',
#  'Why is every question I post on Quora marked as needing clarification?',
#  'Are there any black Amish?',
#  'What is the difference between creativity and innovation? which one is better?',
#  'What do you think of the statement"If everybody likes you, you\'re pretty dull”?',
#  'Why do people use this site?',
#  'What is the difference between goal, aim and dream?',
#  'What were the major contributions of the political leaders during WW1, and how are the compared to the ones during the Franco-Prussian War?',
#  'Why do some people say there are no races?',
#  'How do I import my Facebook friends to Quora?',
#  "My grandfather is a central government employee.he and his wife gets monthly pension.how much pension will his wife get after grandfather's death.?",
#  'Is this move of banning 500 & 1000 Rupee notes right?',
#  'Why is that sign of + used in country code in phone number?',
#  'It is now January 2017. Why do you now regret voting for Trump?',
#  'Is it ok for me to run a business while under a UK Tier 4 student visa?',
#  'How do I download (OS X El Capitan) on PC (Iso)?',
#  'How often do married couples have sex?',
#  'What are the characteristics of metallic bonding?',
#  "What does it feel like to have Asperger's Syndrome?",
#  'Is downloading from torrent is still illegal in India?',
#  "How is the word 'precariously' used in a sentence?",
#  'Why Israel is so important for USA government?',
#  'History of hotel industry?',
#  'Why am I getting cervical mucus when pregnant?',
#  'What is a brindle pug?',
#  'Is a Nagant M1895 revolver a good home defense weapon?',
#  'What are some of the best Bollywood horror movies?',
#  "How will Donald Trump's presidency affect Europe?",
#  "Why can't we use more then one CPU in a game PC? Isn't it possible to make 2 work together?",
#  "Why would my 40-year-old daughter still play that game of 'Dad was a better parent than you'?",
#  'Is their any way you can PM someone on Quora?',
#  'How do I calculate energy savings by using antimicrobial technology?',
#  'What did the U.S. acquire in the Treaty of 1818?',
#  'I have a brilliant idea about a novel. How do I go about writing it?',
#  'Idont want deduction in pf from my?',
#  'Who opposes the Wigmore chart, and why?',
#  'What is the definition of matter?',
#  'How can one acquire a silver tongue, be well spoken, articulate and convincing?',
#  'Have you seen this spectacular evening gala at the G20 Summit—Hangzhou is The most yi?',
#  'India is upgrading its SU30 fighters. To what extent will it bring it closer to a 5th generation fighter and what 5th gen features will it lack?',
#  'How should I prepare for competitive exam?',
#  'What can be done to overcome the fear of flying?',
#  'What are the best things to do before bed to help you sleep?',
#  'What are the most common life mistakes young people make?',
#  'Why do people like Apple products?',
#  'What makes an Indian girl more beautiful?',
#  'What are some of the best songs for an Indian wedding video highlights?',
#  'Will The Amazing Spider-Man 3 happen? If so who will make an appearance?',
#  'A study of students satisfaction towards MBA specializations?',
#  'My father is a peon and yesterday someone insulted me and told me that you are the son of a peon. Why people do so?',
#  "What's after flat design?",
#  'Is it okay to use a pen name on your website?',
#  'What is the worst name in the English language?',
#  'How can I study the Bible?',
#  'What is a proof that hell exists?',
#  'How does an EKG differ from an echocardiogram?',
#  'What does chodikanam means in malayalam?',
#  'How do I get ripped in 3 months?',
#  'Is it possible for an aircraft to have no stall speed, other than 0?',
#  'What does the first day out of prison feel like?',
#  "What's the best way to train muscle endurance?",
#  'What is disaster management in architecture?',
#  'What are some best comments for a girl’s profile picture?',
#  'What are nrutil.h files in the library of C? How can I install them on the Linux (Ubuntu 14.04 LTS) distribution?',
#  'What should I do now? Should I propose her or not?',
#  'What is the schedule for Paris  fall/winter 2013-14 fashion week?',
#  'What is OS X Yosemite?',
#  'I am planning to visit Kerala with my parents. Can anyone suggest me good places and eateries over there and help plan my visit?',
#  'How can I make rs 10000 per month with 1 lakh rupees in India?',
#  'Are there any chances of growing height at the age of 20?',
#  'What does i5 intel 6400 mean?',
#  'Do the Dudley Boys from WWF/WWE time get some endorsements from their old videos which WWE owns at the moment?',
#  'What is the average hourly rate for a freelance mobile app developer experienced on iOS, Android and Blackberry outside of the US?',
#  'What is the key challenges in logistics management today?',
#  "Can you see who views your Instagram even if you're not friends with this person?",
#  'Website with 150,352 views but not a single sale made up-to today. Is it normal?',
#  'What causes conflict?',
#  'Aman Goel how was your JEE preparation during Class 11?',
#  'How do I handle being blackmailed with a video?',
#  'Who are the most popular professors at Harvard Law School?',
#  'How do I add my Yahoo account to Outlook?',
#  "I am very interested in developing an android app so how can I start it right now I don't know its basic requirements too?",
#  'What causes pain under shoulder blades?',
#  'How do I join a game server?',
#  'What is strangeness?',
#  'Why are people so easily offended?',
#  'Which trek is better for a first timer: Dzongri Trek or Sandakphu (with Phalut) trek?',
#  'What were the main countries involved in World War 1? How did they got involved?',
#  'What is an economical accommodation near the American Consulate in Hyderabad?',
#  'How can I properly pop my knee?',
#  'Is dy patil college of engineering of akurdi good?',
#  'Can you drink water after a wisdom tooth extraction with an IV sedation?',
#  'What certification paths are good for a UI Developer career?',
#  'What ways are best to learn linux?',
#  'What is refrigeration?',
#  'Why do some people have pigs for pets?',
#  'How do I ask a question on Quora properly?',
#  'What are some of the best project management tools?',
#  'What is getting out of comfort zone?',
#  'How do I download the Tor browser?',
#  'Why are South Korea and North Korea enemies?',
#  'Can I do an MBA after BE?',
#  'Is it right to dream big?',
#  'How can I prevent acne?',
#  'How can I tell if my iPhone is being remotely accessed or monitored?',
#  'In Breaking Bad Season 3 Episode 10 ("Fly"), did Bryan Cranston take the fall filmed in the scene where he falls from the railings trying to kill the fly in the lab?',
#  'What are covalent bonds? How do they occur?',
#  "What are the main imports and exports of Venezuela, and how does Venezuela's industry compare to Peru's?",
#  'How do I become a safety officer in HPCL and what are the educational qualification needed?',
#  'What should happen to girls who use guys for money and career growth?',
#  'How does Taco Bell make its fried chicken shell taco?',
#  'What are some examples of sentences using the word "palpable"?',
# ...
#  'Is the H1-B visa process truly a pure random lottery selection or is there internally some measurement criteria for selection and rejection of H1-B applications?',
#  'Do jains belong to General category or Other Category?',
#  'Rules of lucky 7 game?',
#  'What does it mean "C is a structured programming language?',
#  'At my late sixties, is it too late to learn to play the piano?',
#  'What can I substitute for a guitar capo?',
#  "What does Trump's popularity tell us about America as a country?",
#  'What was the worst thing your manager has told you?',
#  'What things I need to learn if I want to write a code for predicting football match result(win/draw/loss)?',
#  'What are some Bollywood Movies that were banned in Pakistan?',
#  'Is the Big Bang really the best theory there is? All matter originating from a singularity sounds so much more religious than scientific!',
#  'What are some colors that go well with navy blue?',
#  "I've gained 22 pounds from binge eating and am trying to get back to normal. Will my weight return to normal too?",
#  'What are the powers of prime minister of India?',
#  'How would I able to tell the differences in hip hop/rap music by region?',
#  'Who is the greatest martial artist of all time?',
#  'What does Power Testro contains?',
#  'How many religions in the world are there?',
#  'What might be the business plan in launching reliance jio?',
#  'What should I know about your country?',
#  'How can I build website?',
#  'What are "switchbacks" in hiking?',
#  'What are the career options after graduating from chemical engineering?',
#  'What is a routing protocol?',
#  'How can I write a very short story?',
#  'How do I buy an investment property?',
#  'Are you satisfied with your life?',
#  'What are the strongest fictional characters?',
#  'Do you ever have to leave your house?',
#  "How is Bolivia's geographical location unique in the region, and how does its geography compare to Colombia's?",
#  'How can I accurately measure small amounts of powder (<1g) using only common household materials?',
#  'Is it right to give money to beggar?',
#  'Why is ISRO the most successful?',
#  'How can I increase my visitors to my job blogspot?',
#  "Why is he acting hot'n'cold with me?",
#  'What are the best ways of falling asleep quickly?',
#  'Which months are best for swimming in Dubai?',
#  'Is India secular country?',
#  'Is there a best time to study?',
#  "I don't want to be friends with my negative best friend anymore. What should I do?",
#  'I have leased a car for 36 months with an initial down payment of USD $5720.00 (the car value is USD $19.5k). The monthly payment is USD $450. How much should I charge per day to rent the car to make money?',
#  'Who is the greatest Marvel character and why?',
#  'What are some essential things for wilderness survival?',
#  'What is the best career option for an electrical engineer?',
#  'Can someone translate this image to English?',
#  "What do you do when a girl loves you and you don't love her?",
#  'How can I monetize my website?',
#  'What is the best way to invest money when you have no money?',
#  "Why does Wendy's not use gloves for handling raw meat?",
#  'What are some things new employees should know going into their first day at First Midwest Bank?',
#  'What do a girl feel when a boy touch their boobs?',
#  'How can I download whatsapp backup from Google drive?',
#  'What percentage of questions are yet to be answered in Quora?',
#  'What is your review of Ubuntu 16.04 LTS?',
#  'How does only turning right save gas?',
#  'What creates a wave?',
#  'I had been in a serious relationship with my boyfriend for 3 years. For the last 2 months, we have been fighting a lot and I got very frustrated and irritated with him. During this time I got close to one of my friends and we started liking each other. What should I do?',
#  'What is the difference between CRM and ERP?',
#  'I desperately need money?',
#  'What are your top 10 favorite songs of all time? Why?',
#  'How do you amplify linear motion?',
#  'Is timetravel possible?',
#  "What's the ideology behind cracking games and programs?",
#  'Do jinns and angels really exist?',
#  'How does it feel to be in a relationship with someone with anxiety disorder?',
#  "How do I tell my husband I don't think we're ready to try for a baby yet?",
#  'Are viruses living things? Why or why not?',
#  'What is Leninism and how does it differ from Marxism?',
#  'What are the interivew questions generally they ask in UES?',
#  'Book smart?',
#  "What are the Night King 's powers?",
#  'What are the aims and objectives of education?',
#  'How much energy can a capacitor store?',
#  'To what extent have federal deficits gone up during the Obama administration because of gridlock in Congress?',
#  'Social Welfare: What benefits do governments give people to have children?',
#  'Can a patent really cost up to 10,000 dollars?',
#  'What will we be doing in heaven?',
#  'What do you see, hear, and feel when under the effects of DMT?',
#  'Guidance needed for internship in Computer Science. Should I even try?',
#  'Who is Kumaraswami Kamarajar and who wrote his biography?',
#  'What ever happened to Satoshi from the "Billion to One" card in the alternate reality game Perplex City?',
#  'Who was the captain of Islamic troop while they attack Spain?',
#  'I made intimate contact with a small animal. How can I prevent this in the future?',
#  "How did Life (2017 movie) get greenlit? What's the backstory of how the movie got made?",
#  'What is pse in personals?',
#  'How can you learn to be funny?',
#  'What is a deposit?',
#  'I feel diziness while traveling in the bus and then I vomit . Why does this happen? Is there any treatment to get rid of this?',
#  'What is important in human life?',
#  'After a group is created in "WhatsApp" can I add more people and how is this done?',
#  'How could successful people balance their work and life?',
#  'What are some tips on making it through the job interview process at New Media Investment Group?',
#  'I prepare for IELTS, should I need to have some training course?',
#  'What happens when your eyeball comes out of your socket?',
#  'What are some tips on making it through the job interview process at Snap-on?',
#  'What strategy should be followed for sociology optional?',
#  'Why would UPS send a package to the post office to deliver?',
#  'Why does the solar noon changes every day?',
#  'How do we know our interests?',
#  'What does Richard Muller think of, Resnick-Halliday-Krane, as a physics book, which can build up concepts of physics in a learner?',
#  'What is like to be a chartered accountant in India?',
#  'What is the best way to use time effectively?',
#  'How much does a soft skills trainer earn in India?',
#  'How do I learn quickly?',
#  'What are some powerful open-ended sales questions to ask when dealing with GSA?',
#  'When will CAT 2016 be held?',
#  'How did you learn to speak English?',
#  'Which seasons are the toughest for an actor?',
#  'My husband and his buddies were talking about their sex life in a bar and he shared about us. I feel betrayed. Is my feeling justified? What do I do?',
#  "Why do Chinese people eat bird's nest? Is it good for health or other reasons?",
#  'Which CAD/CAE institute provides good placements?',
#  'Why do Pakistani Muslim Gujjars, Jats and Rajputs have the same culture and clans/gotras as Indian Hindus?',
#  "Is it possible to connect with someone on LinkedIn without 1) having that person's email address and 2) paying a fee?",
#  'Are we in a matrix?',
#  'Are there any Sketchbook-like apps that work on an original iPad?',
#  'Is it better to install your own solar panels or buy energy made in a commercial solar plant?',
#  'Where is the cheapest and nice country to visit?',
#  "How do I know if I'm blocked on WhatsApp?",
#  'What are some laws that should be made to control the high levels of animal trafficking in Guatemala?',
#  'What must one eat to build stamina?',
#  'What was the scariest experience in your life?',
#  'What will the next lighting technology after LED be?',
#  'Do I give people my cell phone number when they ask for my number on WhatsApp?',
#  'How do I cope up with fear of failure?',
#  'What is your review of Abacus?',
#  'Whom Quora moderation consist from?',
#  'What is your biggest fear in life?',
#  'Is there any reason to believe that Christianity is true?',
#  'Why do Indian people think that visa granted to Dolkun Isa as a sign of victory against China? Had Indian media overplay the incident?',
#  'How do you unlock a disabled iPhone 5?',
#  'Can ionic compounds become ionic gases?',
#  'Do airlines compensate doctors for assisting during an emergency?',
#  'Which was your best moment in life?',
#  'What is the worst job for you?',
#  'Should I choose Amity University Mumbai for B.TECH Engineering computer Science with 65% in 12th boards & will I get admission?',
#  "9/11 (terrorist attack): Would the people on the upper floors of the World Trade Centre have eventually been rescued if the towers didn't collapse?",
#  "Why don't I get nightmares?",
#  'How can you become a methodist pastor?',
#  'Can you be pregnant on your period?',
#  'What is the right age to take a kid to a broadway musical?',
#  'Which are some of the best romantic movies?',
#  'Which is the best place for doing a CA CPT in Chennai?',
#  'As measured by the amount of real harm they caused, who were them most notorious American communists in the past 100 years?',
#  'What are Zen Buddhism beliefs?',
#  'I did some data entry work on Upwork, how should I phrase that on my CV?',
#  'What are all the exams can try while preparing for bank exam?',
#  "What should I do if I can't become a doctor?",
#  'Once I finish 6 years on H1B visa do I have to stay out side of USA for 1 year before I can apply for another new term?',
#  'Who created human beings?',
#  'Why is Tracy Chou so talented?',
#  'What are the sketchiest moves you have seen at the poker table that fall in the grey and black areas?',
#  'What do you think of surgical strike against Pakistan by Indian army?',
#  'What is the law of diminishing returns, and why does it occur?',
#  'Why do we consider bi-racial people as still being black? For instance why do we regard Obama as black even though his mother is white?',
#  "Why don't Muslim of India talk about the godhra train burning which triggered Gujrat riots?",
#  'Which are the best hair oils in India for women?',
#  'What are the furniture trends in india?',
#  'How did Germans deal with antisemitism after WWII ended?',
#  'Can I hide the likes and comments in my cover picture from the people who are not my friends in Facebook?',
#  'How can I secretly take screenshots on Snapchat?',
#  'Marrying an IAS officer, even if he asks for 25lacs as dowry will be a good decision for a good future. Should I reconsider?',
#  'Is Egypt safe to travel?',
#  'Does Bhutan give permanent residence to European citizens who want to live a retired life there?',
#  'What is SUSTAINABILITY in product life cycle?',
#  'Why it is important to have a NRE/NRO account for an NRI?',
#  'Whatdo you think about the shape of Filipino Consiousness in natural?',
#  'Which is the best movie ever in Hollywood(new)?',
#  'Is it bad if I can feel warmth from my hard drive in a laptop?',
#  'Software or Application to search mobile number of peoples using whatsup by name and address?',
#  'Who was the "blacksmith" of Daredevil season 2?',
#  'Is the Narcissist often jealous of their scapegoat?',
#  'How do I contact Quora?',
#  'How widely accepted are credit cards at small businesses and restaurants in France?',
#  'Which telugu movie has most heart touching climax?',
#  'How can I reduce my belly and hips fat without doing exercise?',
#  'Can I change my branch in DAVV Indore?',
#  'What are some Men.com logins I can use?',
#  'How do I stop eating junk food?',
#  'What companies partner with tech startups to help build MVPs (coding), in exchange for only equity?',
#  'How can I get a summer internship at Credit-Suisse Pune?',
#  'What are the best laptop buying options available under 50k?',
#  'How may I contribute to the world of open source?',
#  'What will Donald Trump do as President of the United States?',
#  'What are some of the positive and negative implications that could come with time traveling?',
#  'When you type on a keyboard, how many fingers do you use?',
#  'What are the differences, if any, between the Toyota GT-86, FT-86, Scion FR-S, and the Subaru BR-Z?',
#  'How do I keep track of information?',
#  'How can I make an android app using Python 3? Is there any IDE to develop an android app?',
#  'What are the advantages of plastic currency?',
#  'What are some Brake calliper used in Baja SAE India by teams?',
#  'What are the safety precautions on handling shotguns proposed by the NRA in Washington?',
#  'What are some examples of sentences using the word "misconstrue"?',
#  "What is the Night King's weakness?",
#  'What are the physical benefits of an exercise bike?',
#  'Can I still do back workout after deadlift day?',
#  'What is the best exercise to lose weight successfully?',
#  'Why did you marry your wife?',
#  'Why do some Asian women cry during sex?',
#  'How come traffic from Quora comes up as "direct / none" in my Google Analytics reports?',
#  'Why does China support terrorism?',
#  'Can I pay rent to my parents?',
#  'Is a police department only liable for what their officers do while on duty and while responding to a call?',
#  'What is the perfect way to earn money online?',
#  'How can I refresh the screen on my computer?',
#  'Has someone built a robot that can suggest new variations to a home-maker’s recipes and also act like a sous-chef?',
#  'What should I do if my dog is throwing up yellow/white liquid/foam?',
#  'How can I report someone on Quora?',
#  'Why isn’t inverse fast Fourier transform working?',
#  "Is there a real Top Gun school for naval aviators? What's it like?",
#  'Were the original oceans composed of salt water?',
#  'Why is helping the homeless important?',
#  'What are some good things to mix with Malibu rum?',
#  'Traveling to geogira 4 days in tibilis ask for some advise about things to do ,place to vist make me memoriable',
#  'What are the similarities and the differences in the personalities of lady cadets from the Air Force Academy, Officers Training Academy and Indian Naval Academy?',
#  'I got a 46000 rank in Mains and have SC reservation. Can I get an CS in DTU in the first round?',
#  "Which team seeded 9+ is most likely to make it to the Sweet 16 in the 2015 NCAA men's basketball tournament? Why?",
#  'What are some good TV shows I can watch?',
#  'If one completes the entire Free Code Camp program (all available modules), earning all four certificates, would one be prepared for a junior dev job?',
#  'What do people think about China?',
#  'How do I pass an ETG test?',
#  'What should be my strategy to score more than 90% marks in the 12th class board exam in 3 months only from cbse bord?',
#  'How much does a talkspace therapist make an hour?',
#  "Sikhism: Why has the Akal Takht awarded martyrdom to Sawant Singh & Beant Singh (Indira Gandhi's assasins)?",
#  "What's your favorite Android mobile App and why?",
#  'How was KVPY SA 2016?',
#  'How do I avoid distractions and just focus on studies?',
#  'What are basic questions asked by any automobile company in an interview for freshers?',
#  'Did Lord Macaulay really proclaim in the British Parliament that the only way to rule India is to make the Indian culture seem inferior?',
#  'Why do people eat pizza?',
#  'How should I approach a career in animation?',
#  'How can more secular Jews be given a chance to learn about traditional Judaism?',
#  'What are some of the mind blowing facts about NASA?',
#  'Is Duolingo the best and quickest way to learn a new language or is something better available?',
#  "Has any trick or any other way which shows my number on other’s whatsapp account if i saved his/her whatsapp number in my contact list but they've no",
#  'I want to conduct a monohybrid cross with pea. Any suggestions to select a trait and some methods?',
#  'Are there exercises that will not trigger migraines?',
#  "What's the evolutionary reason that sunfish (mola mola) don't have a proper tail?",
#  ...]

# %%
len(text)
# Out:
# 88720

# %%
from sentence_transformers import SentenceTransformer
import torch

# device = 'cuda' if torch.cuda.is_available() else 'cpu'
device = 'mps'

# %%
model = SentenceTransformer('sentence-transformers/all-MiniLM-L6-v2', device = device)
model
# Out:
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# SentenceTransformer(
#   (0): Transformer({'max_seq_length': 256, 'do_lower_case': False}) with Transformer model: BertModel
#   (1): Pooling({'word_embedding_dimension': 384, 'pooling_mode_cls_token': False, 'pooling_mode_mean_tokens': True, 'pooling_mode_max_tokens': False, 'pooling_mode_mean_sqrt_len_tokens': False, 'pooling_mode_weightedmean_tokens': False, 'pooling_mode_lasttoken': False, 'include_prompt': True})
#   (2): Normalize()
# )

# %%
pinecone_creds = json.load(open('PineCone.json'))

# %%
import pinecone
from pinecone import ServerlessSpec


pc = pinecone.Pinecone(api_key = pinecone_creds['PINECONE_API_KEY'])

cloud = 'aws'
region = 'us-east-1'

spec = ServerlessSpec(cloud=cloud, region=region)

# %%
import time
index_name = 'semantic-search'

try:
    
    if index_name not in pc.list_indexes():
        pc.create_index(
            name=index_name,
            dimension=model.get_sentence_embedding_dimension(),
            metric='cosine',
            spec=spec
        )
except Exception as e:
    print(f'Index {index_name} already exists')
index = pc.Index(index_name)
time.sleep(1)
index.describe_index_stats()
# Out:
# {'dimension': 384,
#  'index_fullness': 0.0,
#  'namespaces': {},
#  'total_vector_count': 0}

# %%
from tqdm.auto import tqdm

batch_size = 128

for i in tqdm(range(0, len(text), batch_size)):

    i_end = min(i+batch_size, len(text))
    ids = [str(x) for x in range(i, i_end)]
    metadata = [{'text':question} for question in text[i:i_end]]
    xc = model.encode(text[i:i_end])
    records = zip(ids, xc, metadata)
    index.upsert(vectors=records)

index.describe_index_stats()
# Out:
#   0%|          | 0/694 [00:00<?, ?it/s]
# {'dimension': 384,
#  'index_fullness': 0.0,
#  'namespaces': {'': {'vector_count': 96384}},
#  'total_vector_count': 96384}

# %%
query = 'Which city has the largest population in the world?'

query_encodings = model.encode(query).tolist()

# %%
index.query(vector=query_encodings, top_k=5, include_metadata=True)
# Out:
# {'matches': [{'id': '52232',
#               'metadata': {'text': 'What is the most populated city in the '
#                                    'world?'},
#               'score': 0.874452,
#               'values': []},
#              {'id': '15396',
#               'metadata': {'text': 'Which is the most populated city in the '
#                                    'world.?'},
#               'score': 0.873866737,
#               'values': []},
#              {'id': '11783',
#               'metadata': {'text': 'Which is biggest city in the world?'},
#               'score': 0.857589185,
#               'values': []},
#              {'id': '49790',
#               'metadata': {'text': 'What are the most populated cities in the '
#                                    'world?'},
#               'score': 0.842684507,
#               'values': []},
#              {'id': '56406',
#               'metadata': {'text': 'What is the biggest city?'},
#               'score': 0.799513638,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 6}}

# %%
query = 'Which is the top in demand job?'

query_encodings = model.encode(query).tolist()
index.query(vector=query_encodings, top_k=5, include_metadata=True)
# Out:
# {'matches': [{'id': '9307',
#               'metadata': {'text': 'Which is the best job in the market?'},
#               'score': 0.791630566,
#               'values': []},
#              {'id': '46299',
#               'metadata': {'text': 'Which is Highest paid job in India?'},
#               'score': 0.739718139,
#               'values': []},
#              {'id': '37499',
#               'metadata': {'text': 'Which job has the highest salary?'},
#               'score': 0.73333174,
#               'values': []},
#              {'id': '51465',
#               'metadata': {'text': 'Which are the highest paid jobs in India?'},
#               'score': 0.719765246,
#               'values': []},
#              {'id': '83606',
#               'metadata': {'text': 'What job has the highest salary?'},
#               'score': 0.716074824,
#               'values': []}],
#  'namespace': '',
#  'usage': {'read_units': 6}}
